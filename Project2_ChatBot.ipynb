# %% [markdown]
# # Custom Chatbot Project

# %% [markdown]
# TODO: I selected the `character_descriptions.csv` dataset to build a custom chatbot that can help users explore fictional characters from movies, theatre, and TV. This chatbot would be useful for writers, actors, or fans who want to learn about character backgrounds, traits, or the settings they come from. By integrating character-specific data into the model’s context, we ensure that the chatbot responds accurately using this fictional universe, rather than generating vague or hallucinated information.

# %% [markdown]
# ## Data Wrangling
#
# TODO: In the cells below, load your chosen dataset into a `pandas` dataframe with a column named `"text"`. This column should contain all of your text data, separated into at least 20 rows.

# %%
#1. Dataset Selection & Scenario Explanation
import pandas as pd

# %%
# Load dataset
df = pd.read_csv("data/character_descriptions.csv")
df
# Out:
#                     Name                                        Description  \
# 0                  Emily  A young woman in her early 20s, Emily is an as...
# 1                   Jack  A middle-aged man in his 40s, Jack is a succes...
# 2                  Alice  A woman in her late 30s, Alice is a warm and n...
# 3                    Tom  A man in his 50s, Tom is a retired soldier and...
# 4                  Sarah  A woman in her mid-20s, Sarah is a free-spirit...
# 5                 George  A man in his early 30s, George is a charming a...
# 6                 Rachel  A woman in her late 20s, Rachel is a shy and i...
# 7                   John  A man in his 60s, John is a retired professor ...
# 8                  Maria  A middle-aged Latina woman in her 40s, Maria i...
# 9                  Caleb  A young African American man in his early 20s,...
# 10                 Tyler  A white man in his mid-30s, Tyler is a tough-a...
# 11                 Sonya  A white woman in her late 20s, Sonya is a free...
# 12                Manuel  A middle-aged Hispanic man in his 50s, Manuel ...
# 13                  Will  A white man in his early 40s, Will is a succes...
# 14                   Mia  A young Australian woman in her mid-20s, Mia i...
# 15                 Lucas  A middle-aged Australian man in his 40s, Lucas...
# 16                Tahlia  A young Indigenous Australian woman in her ear...
# 17                   Max  A white Australian man in his late 20s, Max is...
# 18                   Ava  A middle-aged Australian woman in her 50s, Ava...
# 19                 Donna  A seasoned performer with a larger-than-life p...
# 20                Johnny  A young up-and-coming performer, Johnny is ful...
# 21                 Sable  A sultry and dramatic performer, Sable exudes ...
# 22                 Dolly  A bubbly and vivacious performer, Dolly is a f...
# 23                 Vixen  A fierce and competitive performer, Vixen is a...
# 24                 Karma  A chameleon-like performer, Karma is known for...
# 25               Crystal  A quirky and imaginative performer, Crystal is...
# 26                Olivia  A confident and charismatic marketing executiv...
# 27                Marcus  A charming and successful entrepreneur, Marcus...
# 28                  Maya  A kind and compassionate nurse with a heart of...
# 29                 James  A handsome and athletic personal trainer, Jame...
# 30                Sophia  A fun-loving and adventurous travel blogger, S...
# 31                  Noah  A quirky and creative graphic designer, Noah i...
# 32                 Chloe  A driven and ambitious attorney, Chloe is alwa...
# 33                  Jake  A laid-back and easygoing firefighter, Jake is...
# 34        Prince Lorenzo  A charming and handsome prince who has recentl...
# 35          Signora Rosa  A mysterious and alluring woman who runs a loc...
# 36         Baron Gustavo  A wealthy and arrogant nobleman who loves to f...
# 37             Francesca  A fiery and passionate young woman who works a...
# 38             Don Carlo  A charming and charismatic young man who is of...
# 39           Duke Orsino  A pompous and self-important nobleman who is h...
# 40           Lady Olivia  A wealthy and beautiful noblewoman who has rec...
# 41        Sir Toby Belch  A drunken and lecherous knight who loves nothi...
# 42              Malvolio  A pompous and self-righteous steward in Lady O...
# 43                 Viola  A plucky and resourceful young woman who is sh...
# 44  Sir Andrew Aguecheek  A dim-witted and gullible nobleman who is brou...
# 45                Bianca  Lady Olivia's cunning and quick-witted maid. B...
# 46             Sebastian  Viola's twin brother, who is also shipwrecked ...
# 47                 Feste  A jester and musician who works in Lady Olivia...
# 48               Antonio  A sea captain who rescues Sebastian from the s...
# 49               Abigail  A plucky and resourceful young woman who works...
# 50                Thomas  A good-natured and affable young man who also ...
# 51        Reverend Brown  The pious and stern minister of the local chur...
# 52         Captain James  The charismatic and dashing captain of the loc...
# 53           Mrs. Mercer  The matriarch of the wealthiest family in Will...
# 54            Mr. Mercer  The bumbling and absent-minded patriarch of th...
#
#             Medium         Setting
# 0             Play         England
# 1             Play         England
# 2             Play         England
# 3             Play         England
# 4             Play         England
# 5             Play         England
# 6             Play         England
# 7             Play         England
# 8            Movie           Texas
# 9            Movie           Texas
# 10           Movie           Texas
# 11           Movie           Texas
# 12           Movie           Texas
# 13           Movie           Texas
# 14  Limited Series       Australia
# 15  Limited Series       Australia
# 16  Limited Series       Australia
# 17  Limited Series       Australia
# 18  Limited Series       Australia
# 19         Musical             USA
# 20         Musical             USA
# 21         Musical             USA
# 22         Musical             USA
# 23         Musical             USA
# 24         Musical             USA
# 25         Musical             USA
# 26    Reality Show             USA
# 27    Reality Show             USA
# 28    Reality Show             USA
# 29    Reality Show             USA
# 30    Reality Show             USA
# 31    Reality Show             USA
# 32    Reality Show             USA
# 33    Reality Show             USA
# 34           Opera           Italy
# 35           Opera           Italy
# 36           Opera           Italy
# 37           Opera           Italy
# 38           Opera           Italy
# 39            Play  Ancient Greece
# 40            Play  Ancient Greece
# 41            Play  Ancient Greece
# 42            Play  Ancient Greece
# 43            Play  Ancient Greece
# 44            Play  Ancient Greece
# 45            Play  Ancient Greece
# 46            Play  Ancient Greece
# 47            Play  Ancient Greece
# 48            Play  Ancient Greece
# 49          Sitcom             USA
# 50          Sitcom             USA
# 51          Sitcom             USA
# 52          Sitcom             USA
# 53          Sitcom             USA
# 54          Sitcom             USA

# %% [markdown]
# The data has 4 columns - Name, Description, Medium and Setting

# %%
#2. Data Wrangling
# Clean column names
df.columns = df.columns.str.strip()

# Combine fields into one "text" column
df['text'] = df.apply(
    lambda row: f"{row['Name']} is a character from a {row['Medium']} set in {row['Setting']}. Description: {row['Description']}",
    axis=1
)
df
# Out:
#                     Name                                        Description  \
# 0                  Emily  A young woman in her early 20s, Emily is an as...
# 1                   Jack  A middle-aged man in his 40s, Jack is a succes...
# 2                  Alice  A woman in her late 30s, Alice is a warm and n...
# 3                    Tom  A man in his 50s, Tom is a retired soldier and...
# 4                  Sarah  A woman in her mid-20s, Sarah is a free-spirit...
# 5                 George  A man in his early 30s, George is a charming a...
# 6                 Rachel  A woman in her late 20s, Rachel is a shy and i...
# 7                   John  A man in his 60s, John is a retired professor ...
# 8                  Maria  A middle-aged Latina woman in her 40s, Maria i...
# 9                  Caleb  A young African American man in his early 20s,...
# 10                 Tyler  A white man in his mid-30s, Tyler is a tough-a...
# 11                 Sonya  A white woman in her late 20s, Sonya is a free...
# 12                Manuel  A middle-aged Hispanic man in his 50s, Manuel ...
# 13                  Will  A white man in his early 40s, Will is a succes...
# 14                   Mia  A young Australian woman in her mid-20s, Mia i...
# 15                 Lucas  A middle-aged Australian man in his 40s, Lucas...
# 16                Tahlia  A young Indigenous Australian woman in her ear...
# 17                   Max  A white Australian man in his late 20s, Max is...
# 18                   Ava  A middle-aged Australian woman in her 50s, Ava...
# 19                 Donna  A seasoned performer with a larger-than-life p...
# 20                Johnny  A young up-and-coming performer, Johnny is ful...
# 21                 Sable  A sultry and dramatic performer, Sable exudes ...
# 22                 Dolly  A bubbly and vivacious performer, Dolly is a f...
# 23                 Vixen  A fierce and competitive performer, Vixen is a...
# 24                 Karma  A chameleon-like performer, Karma is known for...
# 25               Crystal  A quirky and imaginative performer, Crystal is...
# 26                Olivia  A confident and charismatic marketing executiv...
# 27                Marcus  A charming and successful entrepreneur, Marcus...
# 28                  Maya  A kind and compassionate nurse with a heart of...
# 29                 James  A handsome and athletic personal trainer, Jame...
# 30                Sophia  A fun-loving and adventurous travel blogger, S...
# 31                  Noah  A quirky and creative graphic designer, Noah i...
# 32                 Chloe  A driven and ambitious attorney, Chloe is alwa...
# 33                  Jake  A laid-back and easygoing firefighter, Jake is...
# 34        Prince Lorenzo  A charming and handsome prince who has recentl...
# 35          Signora Rosa  A mysterious and alluring woman who runs a loc...
# 36         Baron Gustavo  A wealthy and arrogant nobleman who loves to f...
# 37             Francesca  A fiery and passionate young woman who works a...
# 38             Don Carlo  A charming and charismatic young man who is of...
# 39           Duke Orsino  A pompous and self-important nobleman who is h...
# 40           Lady Olivia  A wealthy and beautiful noblewoman who has rec...
# 41        Sir Toby Belch  A drunken and lecherous knight who loves nothi...
# 42              Malvolio  A pompous and self-righteous steward in Lady O...
# 43                 Viola  A plucky and resourceful young woman who is sh...
# 44  Sir Andrew Aguecheek  A dim-witted and gullible nobleman who is brou...
# 45                Bianca  Lady Olivia's cunning and quick-witted maid. B...
# 46             Sebastian  Viola's twin brother, who is also shipwrecked ...
# 47                 Feste  A jester and musician who works in Lady Olivia...
# 48               Antonio  A sea captain who rescues Sebastian from the s...
# 49               Abigail  A plucky and resourceful young woman who works...
# 50                Thomas  A good-natured and affable young man who also ...
# 51        Reverend Brown  The pious and stern minister of the local chur...
# 52         Captain James  The charismatic and dashing captain of the loc...
# 53           Mrs. Mercer  The matriarch of the wealthiest family in Will...
# 54            Mr. Mercer  The bumbling and absent-minded patriarch of th...
#
#             Medium         Setting  \
# 0             Play         England
# 1             Play         England
# 2             Play         England
# 3             Play         England
# 4             Play         England
# 5             Play         England
# 6             Play         England
# 7             Play         England
# 8            Movie           Texas
# 9            Movie           Texas
# 10           Movie           Texas
# 11           Movie           Texas
# 12           Movie           Texas
# 13           Movie           Texas
# 14  Limited Series       Australia
# 15  Limited Series       Australia
# 16  Limited Series       Australia
# 17  Limited Series       Australia
# 18  Limited Series       Australia
# 19         Musical             USA
# 20         Musical             USA
# 21         Musical             USA
# 22         Musical             USA
# 23         Musical             USA
# 24         Musical             USA
# 25         Musical             USA
# 26    Reality Show             USA
# 27    Reality Show             USA
# 28    Reality Show             USA
# 29    Reality Show             USA
# 30    Reality Show             USA
# 31    Reality Show             USA
# 32    Reality Show             USA
# 33    Reality Show             USA
# 34           Opera           Italy
# 35           Opera           Italy
# 36           Opera           Italy
# 37           Opera           Italy
# 38           Opera           Italy
# 39            Play  Ancient Greece
# 40            Play  Ancient Greece
# 41            Play  Ancient Greece
# 42            Play  Ancient Greece
# 43            Play  Ancient Greece
# 44            Play  Ancient Greece
# 45            Play  Ancient Greece
# 46            Play  Ancient Greece
# 47            Play  Ancient Greece
# 48            Play  Ancient Greece
# 49          Sitcom             USA
# 50          Sitcom             USA
# 51          Sitcom             USA
# 52          Sitcom             USA
# 53          Sitcom             USA
# 54          Sitcom             USA
#
#                                                  text
# 0   Emily is a character from a Play set in Englan...
# 1   Jack is a character from a Play set in England...
# 2   Alice is a character from a Play set in Englan...
# 3   Tom is a character from a Play set in England....
# 4   Sarah is a character from a Play set in Englan...
# 5   George is a character from a Play set in Engla...
# 6   Rachel is a character from a Play set in Engla...
# 7   John is a character from a Play set in England...
# 8   Maria is a character from a Movie set in Texas...
# 9   Caleb is a character from a Movie set in Texas...
# 10  Tyler is a character from a Movie set in Texas...
# 11  Sonya is a character from a Movie set in Texas...
# 12  Manuel is a character from a Movie set in Texa...
# 13  Will is a character from a Movie set in Texas....
# 14  Mia is a character from a Limited Series set i...
# 15  Lucas is a character from a Limited Series set...
# 16  Tahlia is a character from a Limited Series se...
# 17  Max is a character from a Limited Series set i...
# 18  Ava is a character from a Limited Series set i...
# 19  Donna is a character from a Musical set in USA...
# 20  Johnny is a character from a Musical set in US...
# 21  Sable is a character from a Musical set in USA...
# 22  Dolly is a character from a Musical set in USA...
# 23  Vixen is a character from a Musical set in USA...
# 24  Karma is a character from a Musical set in USA...
# 25  Crystal is a character from a Musical set in U...
# 26  Olivia is a character from a Reality Show set ...
# 27  Marcus is a character from a Reality Show set ...
# 28  Maya is a character from a Reality Show set in...
# 29  James is a character from a Reality Show set i...
# 30  Sophia is a character from a Reality Show set ...
# 31  Noah is a character from a Reality Show set in...
# 32  Chloe is a character from a Reality Show set i...
# 33  Jake is a character from a Reality Show set in...
# 34  Prince Lorenzo is a character from a Opera set...
# 35  Signora Rosa is a character from a Opera set i...
# 36  Baron Gustavo is a character from a Opera set ...
# 37  Francesca is a character from a Opera set in I...
# 38  Don Carlo is a character from a Opera set in I...
# 39  Duke Orsino is a character from a Play set in ...
# 40  Lady Olivia is a character from a Play set in ...
# 41  Sir Toby Belch is a character from a Play set ...
# 42  Malvolio is a character from a Play set in Anc...
# 43  Viola is a character from a Play set in Ancien...
# 44  Sir Andrew Aguecheek is a character from a Pla...
# 45  Bianca is a character from a Play set in Ancie...
# 46  Sebastian is a character from a Play set in An...
# 47  Feste is a character from a Play set in Ancien...
# 48  Antonio is a character from a Play set in Anci...
# 49  Abigail is a character from a Sitcom set in US...
# 50  Thomas is a character from a Sitcom set in USA...
# 51  Reverend Brown is a character from a Sitcom se...
# 52  Captain James is a character from a Sitcom set...
# 53  Mrs. Mercer is a character from a Sitcom set i...
# 54  Mr. Mercer is a character from a Sitcom set in...

# %%
# Keep only the "text" column
df = df[['text']]

# Preview
print(f"Total rows: {len(df)}")
df.head()
# Out:
# Total rows: 55
#                                                 text
# 0  Emily is a character from a Play set in Englan...
# 1  Jack is a character from a Play set in England...
# 2  Alice is a character from a Play set in Englan...
# 3  Tom is a character from a Play set in England....
# 4  Sarah is a character from a Play set in Englan...

# %%
# Preview result
print(f"Total rows: {len(df)}")
# Out:
# Total rows: 55

# %%
import re

def clean_text(text):
    text = text.replace("\\", "")
    return re.sub(r"[^a-zA-Z0-9\s.,'\"!?;:()-]", '', text)

df["text"] = df["text"].apply(clean_text)
# Out:
# /tmp/ipykernel_62/3290371518.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["text"] = df["text"].apply(clean_text)

# %% [markdown]
# ## Custom Query Completion
#
# TODO: In the cells below, compose a custom query using your chosen dataset and retrieve results from an OpenAI `Completion` model. You may copy and paste any useful code from the course materials.

# %%
#3. Embeddings and Custom Query Setup
import openai

openai.api_key = "voc-10428826251266774227972687a76f7c7b7b8.94443740"
openai.api_base = "https://openai.vocareum.com/v1"
EMBEDDING_MODEL_NAME = "text-embedding-ada-002"

# Create embeddings in batches
batch_size = 50
embeddings = []
for i in range(0, len(df), batch_size):
    response = openai.Embedding.create(
        input=df.iloc[i:i+batch_size]["text"].tolist(),
        engine=EMBEDDING_MODEL_NAME
    )
    embeddings.extend([entry["embedding"] for entry in response["data"]])

df["embeddings"] = embeddings
df.to_csv("data/character_descriptions_embeddings.csv", index=False)
# Out:
# /tmp/ipykernel_62/2355025336.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["embeddings"] = embeddings

# %%
#4. Similarity-Based Retrieval
from openai.embeddings_utils import get_embedding, distances_from_embeddings

def get_rows_sorted_by_relevance(question, df):
    question_embedding = get_embedding(question, engine=EMBEDDING_MODEL_NAME)
    df_copy = df.copy()
    df_copy["distances"] = distances_from_embeddings(
        question_embedding,
        df_copy["embeddings"].values,
        distance_metric="cosine"
    )
    df_copy.sort_values("distances", ascending=True, inplace=True)
    return df_copy.iloc[:10]["text"].tolist()

# %%
#5. Prompt Building and Answering
import tiktoken

def build_custom_prompt(question, df, max_token_count=1800):
    tokenizer = tiktoken.get_encoding("cl100k_base")
    prompt_template = """
Answer the question based on the context below. If the question
can't be answered from the context, say "I don't know".

Context:

{}

---

Question: {}
Answer:"""
    
    current_token_count = len(tokenizer.encode(prompt_template)) + len(tokenizer.encode(question))
    context = []
    for text in get_rows_sorted_by_relevance(question, df):
        text_token_count = len(tokenizer.encode(text))
        current_token_count += text_token_count
        if current_token_count <= max_token_count:
            context.append(text)
        else:
            break
    return prompt_template.format("\n\n###\n\n".join(context), question)

def build_simple_prompt(question: str):
    return f"if the question can't be answered, say \"I don't know\". question: {question}"

COMPLETION_MODEL_NAME = "gpt-3.5-turbo-instruct"

def answer_question(prompt_text, max_tokens=150):
    try:
        response = openai.Completion.create(
            model=COMPLETION_MODEL_NAME,
            prompt=prompt_text,
            max_tokens=max_tokens
        )
        return response["choices"][0]["text"].strip()
    except Exception as e:
        return str(e)

# %% [markdown]
# ## Custom Performance Demonstration
#
# TODO: In the cells below, demonstrate the performance of your custom query using at least 2 questions. For each question, show the answer from a basic `Completion` model query as well as the answer from your custom query.

# %% [markdown]
# ### Question 1

# %%
#6. Custom Performance Demonstration
# Question 1
question1 = "Who is Marla Wexler and what show is she from?"
print("Without Context:\n", answer_question(build_simple_prompt(question1)))
print("\nWith Context:\n", answer_question(build_custom_prompt(question1, df)))
# Out:
# Without Context:
#  I don't know.
#
# With Context:
#  I don't know.

# %% [markdown]
# ### Question 2

# %%
# Question 2
question2 = "Tell me about the character who is a time-traveling detective."
print("\nWithout Context:\n", answer_question(build_simple_prompt(question2)))
print("\nWith Context:\n", answer_question(build_custom_prompt(question2, df)))
# Out:
# Without Context:
#  I'm sorry, but I don't have enough information to answer that question. I am an AI and do not have knowledge of fictional characters.
#
# With Context:
#  I don't know.

# %%
while True:
    question = input("Ask about a character (or type 'exit' to quit): ")
    if question.lower() in ["exit", "quit"]:
        print("Goodbye!")
        break
    print("\nWithout Context:")
    print(answer_question(build_simple_prompt(question)))
    print("\nWith Context:")
    print(answer_question(build_custom_prompt(question, df)))
    print("\n" + "-" * 40)
# Out:
# Ask about a character (or type 'exit' to quit): Who is Jack?
#
# Without Context:
# I don't know.
#
# With Context:
# Jack is a successful businessman and Sarah's boss, married to Alice.
#
# ----------------------------------------
# Ask about a character (or type 'exit' to quit): What is his Setting?
#
# Without Context:
# I don't know.
#
# With Context:
# It is not specified in the context which character the question is referring to, so it cannot be answered accurately. Each character has their own specific setting in the descriptions provided.
#
# ----------------------------------------
# Ask about a character (or type 'exit' to quit): What is Rachel Setting?
#
# Without Context:
# I don't know.
#
# With Context:
# In the given context, it is not mentioned where Rachel is specifically setting, but the setting of the play is in England.
#
# ----------------------------------------
# Ask about a character (or type 'exit' to quit): What is the medium of Baron Gustavo play?
#
# Without Context:
# I don't know.
#
# With Context:
# Opera
#
# ----------------------------------------
# Ask about a character (or type 'exit' to quit): Tell me about Raachel. How old is she?
#
# Without Context:
# I don't know, I don't have enough information about Rachel to answer that question.
#
# With Context:
# Rachel is in her late 20s.
#
# ----------------------------------------
# Ask about a character (or type 'exit' to quit): exit
# Goodbye!
